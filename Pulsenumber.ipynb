# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import math

import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation


# np.set_printoptions(threshold=20)
arrays=np.genfromtxt('output_puppi_57355_J1713+0747_4852.txt')
np.genfromtxt('output_puppi_57355_J1713+0747_4852.txt', dtype=None)

# print len(arrays)
# Out:
# array([('puppi_57355_J1713+0747_4852.11y.x.norm', 0, 0, 0.0, 0.0, 'mJy'),
#        ('puppi_57355_J1713+0747_4852.11y.x.norm', 0, 1, 0.0, 0.0, 'mJy'),
#        ('puppi_57355_J1713+0747_4852.11y.x.norm', 0, 2, 0.0, 0.0, 'mJy'),
#        ...,
#        ('puppi_57355_J1713+0747_4852.11y.x.norm', 14, 445, 0.0, 0.0, 'mJy'),
#        ('puppi_57355_J1713+0747_4852.11y.x.norm', 14, 446, 0.0, 0.0, 'mJy'),
#        ('puppi_57355_J1713+0747_4852.11y.x.norm', 14, 447, 0.0, 0.0, 'mJy')],
#       dtype=[('f0', 'S38'), ('f1', '<i8'), ('f2', '<i8'), ('f3', '<f8'), ('f4', '<f8'), ('f5', 'S3')])

# %%
time=arrays[:,1]
frequency=arrays[:,2]
flux=arrays[:,3]

fig=plt.figure()
ax=fig.gca(projection='3d')

ax.set_xlabel('time')
ax.set_ylabel('frequency')
ax.set_zlabel('flux')

ax.plot(time, frequency, flux, 'k')

# for angle in range(0, 360):
#     ax.view_init(15, angle)
#     plt.draw()
# rotanimate(ax, angles,'movie.gif',delay=20)

# %%
################
#FOR TIME=0
# time_4852=arrays[range(0, 446),1]
frequency_0=arrays[range(0, 446),2]
flux_0=arrays[range(0, 446),3]

#FOR TIME=1
frequency_1=arrays[range(447, 893),2]
flux_1=arrays[range(447,893),3]

#FOR TIME=2
frequency_2=arrays[range(893, 1340),2]
flux_2=arrays[range(893, 1340),3]

# %%
plt.fill(frequency_2, flux_2 + 1.5, 'w')
plt.fill(frequency_1, flux_1 + 0.75, 'w')
plt.fill(frequency_0, flux_0, 'w')

# %%
n=0
m=6273
mb=6720
fig = plt.figure(figsize=(10,6))
# cmap = mpl.cm.gist_rainbow
nsteps = 14


#Attempting to forloop without an integer. Can do: use _ as placeholder and range to provide amount of times
#Now trying to get rid of the black lines between plots

for i in range(nsteps):
    frequency = arrays[range(m, mb), 2]
    flux = arrays[range(m, mb), 3] + 9.75 - n
#     plt.plot(frequency, flux,'k')
    plt.fill(frequency, flux, 'w')
#     plt.fill_between(frequency, flux, color=cmap(i / float(nsteps)))
#     plt.axis('off')
    m = m - 447
    mb = mb - 447
    n = n + 0.75

# %%
plt.fill?

# %%
arrays[range(m, mb), 2] + 9.75
# Out:
# array([  24.75,   25.75,   26.75,   27.75,   28.75,   29.75,   30.75,
#          31.75,   32.75,   33.75,   34.75,   35.75,   36.75,   37.75,
#          38.75,   39.75,   40.75,   41.75,   42.75,   43.75,   44.75,
#          45.75,   46.75,   47.75,   48.75,   49.75,   50.75,   51.75,
#          52.75,   53.75,   54.75,   55.75,   56.75,   57.75,   58.75,
#          59.75,   60.75,   61.75,   62.75,   63.75,   64.75,   65.75,
#          66.75,   67.75,   68.75,   69.75,   70.75,   71.75,   72.75,
#          73.75,   74.75,   75.75,   76.75,   77.75,   78.75,   79.75,
#          80.75,   81.75,   82.75,   83.75,   84.75,   85.75,   86.75,
#          87.75,   88.75,   89.75,   90.75,   91.75,   92.75,   93.75,
#          94.75,   95.75,   96.75,   97.75,   98.75,   99.75,  100.75,
#         101.75,  102.75,  103.75,  104.75,  105.75,  106.75,  107.75,
#         108.75,  109.75,  110.75,  111.75,  112.75,  113.75,  114.75,
# ...
